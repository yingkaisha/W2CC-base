# %%
import os
import yaml
import copy
import time
import numpy as np
import pandas as pd
import xarray as xr

# %%
dict_rename = {
    'PRECT_30d_default': 'PRECT_30d',
    'PRECT_max_default': 'PRECT_max',
    'PRECT_mean_default': 'PRECT_mean',
    'TREFHTMN_min_default': 'T2_1h_min',
    'TREFHTMX_max_default': 'T2_1h_max',
    'TREFHT_30d_default': 'T2_30d_max',
    'TREFHT_max_default': 'T2_1d_max',
    'TREFHT_mean_default': 'T2_1d_mean',
    'TREFHT_min_default': 'T2_1d_min'
}

# %%
# ============================================================== #
# Save all
# ============================================================== #
stn_names = ['Fairbanks', 'Pituffik', 'Guam', 'Yuma_PG', 'Fort_Bragg']

list_ds = []
for stn in stn_names:
    fn1 = f'/glade/derecho/scratch/ksha/EPRI_data/METRICS/{stn}/' + "CESM_STN.zarr"
    ds1 = xr.open_zarr(fn1)
    ds1 = ds1.rename({v: f'{stn}_{v}' for v in ds1.data_vars})
    
    try:
        ds1 = ds1.drop_vars(['lat', 'lon'], errors='ignore')
    except:
        pass
        
    if "valid_year" in ds1.data_vars:
        ds1 = ds1.set_coords("valid_year")
    
    fn2 = f'/glade/derecho/scratch/ksha/EPRI_data/METRICS_STN/{stn}/' + "CESM_member_metrics.zarr"
    ds2 = xr.open_zarr(fn2)
    ds2 = ds2.rename(dict_rename)
    ds2 = ds2.rename({v: f'{stn}_simple_{v}' for v in ds2.data_vars})
    
    try:
        ds2 = ds2.drop_vars(['lat', 'lon'], errors='ignore')
    except:
        pass
        
    if "valid_year" in ds1.data_vars:
        ds2 = ds2.set_coords("valid_year")

    ds = xr.merge([ds1, ds2])
    raise
    list_ds.append(ds)

ds_all = xr.merge(list_ds)

ds_all = ds_all.drop_vars(['quantile',])

save_name = '/glade/derecho/scratch/ksha/EPRI_data/METRICS/STN_CESM_ALL_20260604.zarr'
ds_all.to_zarr(save_name, mode='w')
print(save_name)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 34
#      31         ds2 = ds2.set_coords("valid_year")
#      33     ds = xr.merge([ds1, ds2])
# ---> 34     raise
#      35     list_ds.append(ds)
#      37 ds_all = xr.merge(list_ds)
#
# RuntimeError: No active exception to reraise

# %% [markdown]
# ## ERA5

# %%
stn_names = ['Fairbanks', 'Pituffik', 'Guam', 'Yuma_PG', 'Fort_Bragg']

list_ds = []
for stn in stn_names:
    fn1 = f'/glade/derecho/scratch/ksha/EPRI_data/METRICS/{stn}/' + "ERA5_STN.zarr"
    ds1 = xr.open_zarr(fn1)
    ds1 = ds1.rename({v: f'{stn}_{v}' for v in ds1.data_vars})
    
    try:
        ds1 = ds1.drop_vars(['lat', 'lon'], errors='ignore')
        ds1 = ds1.drop_vars(['latitude', 'longitude'], errors='ignore')
    except:
        pass
        
    # keep valid_year shared across stations (don't prefix it)
    if "valid_year" in ds1.data_vars:
        ds1 = ds1.set_coords("valid_year")

    fn2 = f'/glade/derecho/scratch/ksha/EPRI_data/METRICS_STN/{stn}/' + "ERA5_metrics.zarr"
    ds2 = xr.open_zarr(fn2)
    ds2 = ds2.rename(dict_rename)
    ds2 = ds2.rename({v: f'{stn}_simple_{v}' for v in ds2.data_vars})
    
    try:
        ds2 = ds2.drop_vars(['lat', 'lon'], errors='ignore')
        ds2 = ds2.drop_vars(['latitude', 'longitude'], errors='ignore')
    except:
        pass
        
    # keep valid_year shared across stations (don't prefix it)
    if "valid_year" in ds2.data_vars:
        ds2 = ds2.set_coords("valid_year")
    
    ds = xr.merge([ds1, ds2])
    
    list_ds.append(ds)

ds_all = xr.merge(list_ds)

ds_all = ds_all.drop_vars(['quantile',])

save_name = '/glade/derecho/scratch/ksha/EPRI_data/METRICS/STN_ERA5_ALL_20260604.zarr'
ds_all.to_zarr(save_name, mode='w')
print(save_name)
# Out:
# /glade/derecho/scratch/ksha/EPRI_data/METRICS/STN_ERA5_ALL_20260604.zarr

# %%
ds_all
# Out:
# <xarray.Dataset> Size: 24kB
# Dimensions:                       (valid_year: 68, year: 68)
# Coordinates:
#   * valid_year                    (valid_year) int64 544B 1958 1959 ... 2025
#   * year                          (year) int64 544B 1958 1959 1960 ... 2024 2025
# Data variables: (12/69)
#     Fairbanks_T2_1d_max           (valid_year) float32 272B dask.array<chunksize=(68,), meta=np.ndarray>
#     Fairbanks_T2_1h_max           (valid_year) float32 272B dask.array<chunksize=(68,), meta=np.ndarray>
#     Fairbanks_T2_30d_max          (valid_year) float32 272B dask.array<chunksize=(68,), meta=np.ndarray>
#     Fairbanks_T2_7d_max           (valid_year) float32 272B dask.array<chunksize=(68,), meta=np.ndarray>
#     Fairbanks_simple_PRECT_30d    (year) float32 272B dask.array<chunksize=(1,), meta=np.ndarray>
#     Fairbanks_simple_PRECT_max    (year) float32 272B dask.array<chunksize=(1,), meta=np.ndarray>
#     ...                            ...
#     Fort_Bragg_simple_T2_1h_min   (year) float32 272B dask.array<chunksize=(1,), meta=np.ndarray>
#     Fort_Bragg_simple_T2_1h_max   (year) float32 272B dask.array<chunksize=(1,), meta=np.ndarray>
#     Fort_Bragg_simple_T2_30d_max  (year) float32 272B dask.array<chunksize=(1,), meta=np.ndarray>
#     Fort_Bragg_simple_T2_1d_max   (year) float32 272B dask.array<chunksize=(1,), meta=np.ndarray>
#     Fort_Bragg_simple_T2_1d_mean  (year) float32 272B dask.array<chunksize=(1,), meta=np.ndarray>
#     Fort_Bragg_simple_T2_1d_min   (year) float32 272B dask.array<chunksize=(1,), meta=np.ndarray>
# Attributes:
#     long_name:   Maximum temperature at 2 metres since previous post-processing
#     short_name:  mx2t
#     units:       K
