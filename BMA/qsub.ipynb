# %%
import os
import sys
import yaml
import numpy as np
import xarray as xr
from glob import glob

# %%
conf = {
    'qsub': {
        'qsub_loc': '/glade/u/home/ksha/W2CC-base/qsub/',
        'scripts_loc': '/glade/u/home/ksha/W2CC-base/BMA/scripts/'
    }
}

# %% [markdown]
# ### BMA

# %%
lat_ind = np.arange(192)

# %%
for i, lat_i in enumerate(lat_ind):
    
    f = open('{}BMA_T2_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N BMA_T2
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=16:mem=160GB
#PBS -q casper
#PBS -o BMA_T2.log
#PBS -e BMA_T2.err

conda activate credit
cd {}
python BMA_coef_T2.py {}
'''.format(conf['qsub']['scripts_loc'], lat_i)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_bma_t2_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, lat_i in enumerate(lat_ind):
    print('qsub BMA_T2_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
# for i in range(3232811, 3232939):
#     print(f'qdel {i}')

# %%
for i, lat_i in enumerate(lat_ind):
    
    f = open('{}EMOS_TMAX_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N EMOS_TMAX
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=32:mem=320GB
#PBS -q casper
#PBS -o EMOS_TMAX.log
#PBS -e EMOS_TMAX.err

conda activate credit
cd {}
python EMOS_coef_TMAX.py {}
'''.format(conf['qsub']['scripts_loc'], lat_i)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_emos_tmax_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, lat_i in enumerate(lat_ind):
    print('qsub EMOS_TMAX_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
for i, lat_i in enumerate(lat_ind):
    
    f = open('{}EMOS_TMIN_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N EMOS_TMIN
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=32:mem=320GB
#PBS -q casper
#PBS -o EMOS_TMIN.log
#PBS -e EMOS_TMIN.err

conda activate credit
cd {}
python EMOS_coef_TMIN.py {}
'''.format(conf['qsub']['scripts_loc'], lat_i)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_emos_tmin_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, lat_i in enumerate(lat_ind):
    print('qsub EMOS_TMIN_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
for i, lat_i in enumerate(lat_ind):
    
    f = open('{}EMOS_TP_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N EMOS_TP
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=32:mem=320GB
#PBS -q casper
#PBS -o EMOS_TP.log
#PBS -e EMOS_TP.err

conda activate credit
cd {}
python EMOS_coef_TP.py {}
'''.format(conf['qsub']['scripts_loc'], lat_i)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_emos_tp_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, lat_i in enumerate(lat_ind):
    print('qsub EMOS_TP_{:03d}.sh'.format(i), file=f)
    
f.close()

# %% [markdown]
# ### Quamtile-mapping

# %%
for i, lat_i in enumerate(lat_ind):
    
    f = open('{}EMOS_QM_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N EMOS_QM
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=16:mem=160GB
#PBS -q casper
#PBS -o EMOS_QM.log
#PBS -e EMOS_QM.err

conda activate credit
cd {}
python quantile_opt.py {}
'''.format(conf['qsub']['scripts_loc'], lat_i)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_emos_qm_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, lat_i in enumerate(lat_ind):
    print('qsub EMOS_QM_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
for i, lat_i in enumerate(lat_ind):
    
    f = open('{}EMOS_QM_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N EMOS_QM
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=16:mem=160GB
#PBS -q casper
#PBS -o EMOS_QM.log
#PBS -e EMOS_QM.err

conda activate credit
cd {}
python quantile_infer.py {}
'''.format(conf['qsub']['scripts_loc'], lat_i)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_emos_qm_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, lat_i in enumerate(lat_ind):
    print('qsub EMOS_QM_{:03d}.sh'.format(i), file=f)
    
f.close()

# %% [markdown]
# ### CRPS

# %%
f = open('{}VERIF_CRPS.sh'.format(conf['qsub']['qsub_loc']), 'w') 

heads = '''#!/bin/bash -l

#PBS -N CRPS
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=32:mem=320GB
#PBS -q casper
#PBS -o CRPS.log
#PBS -e CRPS.err

conda activate credit
cd {}
python BMA_VERIF_T2.py
'''.format(conf['qsub']['scripts_loc'])

print(heads, file=f)
f.close()

# %% [markdown]
# ### CSGD TP

# %%
for i, lat_i in enumerate(lat_ind):
    
    f = open('{}EMOS_TP_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N CSGD_TP
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=32:mem=320GB
#PBS -q casper
#PBS -o EMOS_TP.log
#PBS -e EMOS_TP.err

conda activate credit
cd {}
python EMOS_CSGD_coef.py {}
'''.format(conf['qsub']['scripts_loc'], lat_i)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_emos_tp_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, lat_i in enumerate(lat_ind):
    print('qsub EMOS_TP_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
for i in range(50):
    
    f = open('{}EMOS_dress_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N QM_dress
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=32:mem=320GB
#PBS -q casper
#PBS -o EMOS_dress.log
#PBS -e EMOS_dress.err

conda activate credit
cd {}
python Dressing_QM.py
'''.format(conf['qsub']['scripts_loc'])
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_emos_dress_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i in range(50):
    print('qsub EMOS_dress_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
for i in range(50):
    
    f = open('{}Log_dress_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N Lognorm_dress
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=32:mem=320GB
#PBS -q casper
#PBS -o Log_dress.log
#PBS -e Log_dress.err

conda activate credit
cd {}
python Dressing_Lognorm.py
'''.format(conf['qsub']['scripts_loc'])
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_log_dress_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i in range(50):
    print('qsub Log_dress_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
# for i in range(3165551, 3165625):
#     print(f'qdel {i}')
