# %% [markdown]
# # Generate qsub scripts for ERA5 data preparation

# %%
import os
import sys
import yaml
import numpy as np
import xarray as xr

# %%
# sys.path.insert(0, os.path.realpath('../libs/'))
# import preprocess_utils as pu

# %%
conf = {
    'qsub': {
        'qsub_loc': '/glade/u/home/ksha/EPRI-prep/qsub/',
        'scripts_loc': '/glade/u/home/ksha/EPRI-prep/CESM/scripts/'
    }
}

# %%
years = np.arange(1958, 2026)

# %%
# :mem=256GB
for i_year, year in enumerate(years):
    
    f = open('{}ERA5_pack_{}.sh'.format(conf['qsub']['qsub_loc'], year), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N {}
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=16:mem=256GB
#PBS -q casper
#PBS -o {}.log
#PBS -e {}.err

conda activate credit
cd {}
python ERA5_grid_mapping.py {}
'''.format(year, year, year, 
           conf['qsub']['scripts_loc'], 
           year)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_ERA5_pack.sh'.format(conf['qsub']['qsub_loc']), 'w')
for i_year, year in enumerate(years):
    print('qsub ERA5_pack_{}.sh'.format(year), file=f)
f.close()

# %% [markdown]
# ## CESM-DP

# %%
years = np.arange(1958, 2020)

# %%
# :mem=256GB
for i_year, year in enumerate(years):
    
    f = open('{}DP_pack_{}.sh'.format(conf['qsub']['qsub_loc'], year), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N {}
#PBS -A P48500028
#PBS -l walltime=8:59:59
#PBS -l select=1:ncpus=8:mem=128GB
#PBS -q casper
#PBS -o {}.log
#PBS -e {}.err

conda activate credit
cd {}
python DATA00_CESM_FULL_packing.py {}
'''.format(year, year, year, 
           conf['qsub']['scripts_loc'], 
           year)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_DP_pack.sh'.format(conf['qsub']['qsub_loc']), 'w')
for i_year, year in enumerate(years):
    print('qsub DP_pack_{}.sh'.format(year), file=f)
f.close()

# %%
years = np.arange(1958, 2020)

years = [1958, 1960, 1966]

# %%
for i_year, year in enumerate(years):
    
    f = open('{}DP_pack_{}.sh'.format(conf['qsub']['qsub_loc'], year), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N {}
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=32:mem=384GB
#PBS -q casper
#PBS -o {}.log
#PBS -e {}.err

conda activate credit
cd {}
python DATA00_CESM_OCN_packing.py {}
'''.format(year, year, year, 
           conf['qsub']['scripts_loc'], 
           year)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_DP_pack.sh'.format(conf['qsub']['qsub_loc']), 'w')
for i_year, year in enumerate(years):
    print('qsub DP_pack_{}.sh'.format(year), file=f)
f.close()

# %% [markdown]
# ## CESM2-SMYLE subsetting

# %%
years = np.arange(1958, 2020)

# %%
for i_year, year in enumerate(years):
    
    f = open('{}CESM_pack_{}.sh'.format(conf['qsub']['qsub_loc'], year), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N {}
#PBS -A NAML0001
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=8:mem=64GB
#PBS -q casper
#PBS -o {}.log
#PBS -e {}.err

conda activate credit
cd {}
python GRID_00_CESM2.py {}
'''.format(year, year, year, 
           conf['qsub']['scripts_loc'], 
           year)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_CESM_pack.sh'.format(conf['qsub']['qsub_loc']), 'w')
for i_year, year in enumerate(years):
    print('qsub CESM_pack_{}.sh'.format(year), file=f)
f.close()
