# %%
import os
import yaml
import copy

import numpy as np
import pandas as pd
import xarray as xr
import xesmf as xe

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Global data interp

# %%
varnames = [
    'total_column_water',
    'surface_pressure',
    '2m_temperature',
    'minimum_2m_temperature_since_previous_post_processing', 
    'maximum_2m_temperature_since_previous_post_processing', 
    '2m_dewpoint_temperature',
    '10m_u_component_of_wind',
    '10m_v_component_of_wind',
    'total_precipitation',
    'surface_solar_radiation_downwards',
    'surface_thermal_radiation_downwards',
    'geopotential',
    'mean_sea_level_pressure'
]

# %%
year = 1958

ERA5_1h = xr.open_zarr(
    "gs://gcp-public-data-arco-era5/ar/full_37-1h-0p25deg-chunk-1.zarr-v3",
    chunks=None,
    storage_options=dict(token='anon'),)

ERA5_1h = ERA5_1h[varnames]
ERA5_1h = ERA5_1h.sel(level=500) # 500 hPa GP

ds = ERA5_1h.sel(time=slice(f'{year-1}-12-01T00', f'{year}-12-31T23'))
ds = ds.rename({'longitude': 'lon', 'latitude': 'lat'})

ds_tp = ds[['total_precipitation',]]
ds_ave = ds[list(set(varnames)-set(['total_precipitation',]))]

time_start = '{}-12-31T00'.format(year-1)
time_start_save = '{}-01-01T00'.format(year)
time_end = '{}-1-31T23'.format(year)

ds_tp = ds_tp.sel(time=slice(time_start, time_end))
ds_tp = ds_tp.shift(time=-1)
ds_tp = ds_tp.resample(time='24h').sum()
ds_tp['time'] = ds_tp['time'] + pd.Timedelta(hours=24)
ds_tp = ds_tp.sel(time=slice(time_start_save, time_end))

ds_ave = ds_ave.sel(time=slice(time_start, time_end))
ds_ave = ds_ave.resample(time='24h').mean()
ds_ave = ds_ave.sel(time=slice(time_start_save, time_end))
ds_final = xr.merge([ds_tp, ds_ave])

# %%
fn_CESM = '/glade/derecho/scratch/ksha/EPRI_data/CESM2_SMYLE/SMYLE_1958-11-01_daily_ensemble.zarr'
ds_CESM = xr.open_zarr(fn_CESM)
# ds_CESM['lon'] = (ds_CESM['lon']  + 180) % 360 - 180
regridder = xe.Regridder(ds_final, ds_CESM, method='bilinear')
ds_interp = regridder(ds_final)

# %%
# ds_interp = ds_interp.chunk({"time": 32, "lat": 192, "lon": 288})

# # ==================================================================== #
# # encoding
# dict_encoding = {}
# varnames = list(ds_interp.keys())
# varname_4D = []

# chunk_size_3d = dict(chunks=(32, 192, 288))
# chunk_size_4d = dict(chunks=(32, 12, 192, 288))
# compress = zarr.Blosc(cname='zstd', clevel=1, shuffle=zarr.Blosc.SHUFFLE, blocksize=0)

# for i_var, var in enumerate(varnames):
#     if var in varname_4D:
#         dict_encoding[var] = {'compressor': compress, **chunk_size_4d}
#     else:
#         dict_encoding[var] = {'compressor': compress, **chunk_size_3d}

# # ==================================================================== #
# # save
# save_name = f'/glade/derecho/scratch/ksha/EPRI_data/ERA5_grid/ERA5_{year}.zarr'
# ds_interp.to_zarr(save_name, mode='w', consolidated=True, compute=True, encoding=dict_encoding)

# %%
year = 2000
save_name = f'/glade/derecho/scratch/ksha/EPRI_data/ERA5_grid/ERA5_{year}.zarr'

# %%
ds = xr.open_zarr(save_name)

# %%
ds['geopotential'].values
# Out:
# array([[[49437.066, 49437.066, 49437.066, ..., 49437.066, 49437.066,
#          49437.066],
#         [49460.723, 49460.676, 49460.61 , ..., 49460.812, 49460.82 ,
#          49460.777],
#         [49477.523, 49476.266, 49474.98 , ..., 49480.953, 49479.87 ,
#          49478.72 ],
#         ...,
#         [50827.24 , 50833.32 , 50839.215, ..., 50807.81 , 50814.426,
#          50820.934],
#         [50717.547, 50721.2  , 50724.81 , ..., 50706.215, 50710.047,
#          50713.844],
#         [50594.594, 50594.594, 50594.594, ..., 50594.594, 50594.594,
#          50594.594]],
#
#        [[49113.156, 49113.156, 49113.156, ..., 49113.156, 49113.156,
#          49113.156],
#         [49144.19 , 49143.42 , 49142.67 , ..., 49146.473, 49145.715,
#          49144.977],
#         [49154.316, 49151.965, 49149.637, ..., 49161.35 , 49159.04 ,
#          49156.664],
#         ...,
#         [51131.88 , 51135.242, 51138.496, ..., 51120.797, 51124.605,
#          51128.332],
#         [51219.758, 51221.855, 51223.98 , ..., 51213.445, 51215.562,
#          51217.676],
#         [51281.715, 51281.715, 51281.715, ..., 51281.715, 51281.715,
#          51281.715]],
#
#        [[48858.105, 48858.105, 48858.105, ..., 48858.105, 48858.105,
#          48858.105],
#         [48861.242, 48860.766, 48860.285, ..., 48862.773, 48862.24 ,
#          48861.734],
#         [48820.793, 48818.324, 48815.93 , ..., 48828.414, 48825.9  ,
#          48823.336],
#         ...,
#         [50330.93 , 50335.805, 50340.715, ..., 50316.547, 50321.266,
#          50326.082],
#         [50522.62 , 50525.805, 50529.105, ..., 50513.664, 50516.594,
#          50519.51 ],
#         [50782.69 , 50782.69 , 50782.69 , ..., 50782.69 , 50782.69 ,
#          50782.69 ]],
#
#        ...,
#
#        [[50652.047, 50652.047, 50652.047, ..., 50652.047, 50652.047,
#          50652.047],
#         [50684.246, 50685.113, 50685.98 , ..., 50681.65 , 50682.51 ,
#          50683.375],
#         [50721.07 , 50722.258, 50723.51 , ..., 50717.805, 50718.91 ,
#          50719.96 ],
#         ...,
#         [51784.83 , 51794.06 , 51803.17 , ..., 51756.316, 51765.934,
#          51775.445],
#         [51878.266, 51883.086, 51887.945, ..., 51863.777, 51868.594,
#          51873.43 ],
#         [51966.16 , 51966.16 , 51966.16 , ..., 51966.16 , 51966.16 ,
#          51966.16 ]],
#
#        [[50469.426, 50469.426, 50469.426, ..., 50469.426, 50469.426,
#          50469.426],
#         [50475.746, 50475.242, 50474.766, ..., 50477.348, 50476.8  ,
#          50476.26 ],
#         [50496.66 , 50496.062, 50495.54 , ..., 50498.887, 50498.105,
#          50497.355],
#         ...,
#         [51603.816, 51604.945, 51605.92 , ..., 51599.66 , 51601.184,
#          51602.57 ],
#         [51697.633, 51698.227, 51698.816, ..., 51695.98 , 51696.55 ,
#          51697.08 ],
#         [51800.387, 51800.387, 51800.387, ..., 51800.387, 51800.387,
#          51800.387]],
#
#        [[50669.734, 50669.734, 50669.734, ..., 50669.734, 50669.734,
#          50669.734],
#         [50718.793, 50717.344, 50715.902, ..., 50722.977, 50721.61 ,
#          50720.18 ],
#         [50750.125, 50747.297, 50744.53 , ..., 50758.465, 50755.73 ,
#          50752.938],
#         ...,
#         [50766.523, 50766.82 , 50767.016, ..., 50764.95 , 50765.598,
#          50766.133],
#         [50799.8  , 50800.56 , 50801.4  , ..., 50797.547, 50798.293,
#          50799.05 ],
#         [50868.703, 50868.703, 50868.703, ..., 50868.703, 50868.703,
#          50868.703]]], dtype=float32)

# %% [markdown]
# ## Land-Sea Mask prep

# %%
ERA5_1h = xr.open_zarr(
    "gs://gcp-public-data-arco-era5/ar/full_37-1h-0p25deg-chunk-1.zarr-v3",
    chunks=None,
    storage_options=dict(token='anon'),)

ds_final = ERA5_1h[['land_sea_mask']].isel(time=800000)

fn_CESM = '/glade/derecho/scratch/ksha/EPRI_data/CESM2_SMYLE/SMYLE_1958-11-01_daily_ensemble.zarr'
ds_CESM = xr.open_zarr(fn_CESM)
# ds_CESM['lon'] = (ds_CESM['lon']  + 180) % 360 - 180
regridder = xe.Regridder(ds_final, ds_CESM, method='bilinear')
ds_interp = regridder(ds_final)

# %%
# ds_interp.to_zarr('/glade/derecho/scratch/ksha/EPRI_data/static/static.zarr')
