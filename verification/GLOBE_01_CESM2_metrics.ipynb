# %%
import os
import yaml
import copy
import time
import numpy as np
import pandas as pd
import xarray as xr

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Inter-annual

# %% [markdown]
# ### Default

# %%
save_dir = f'/glade/derecho/scratch/ksha/EPRI_data/METRICS_GLOBE/'
base_dir = '/glade/derecho/scratch/ksha/EPRI_data/CESM2_SMYLE/'

# %%
var_map = ["TREFHT", "TREFHTMX", "PRECT"]
list_per_verif = []

# cache: init_file -> ensemble-mean dataset (lazy dask ok)
_cache = {}

for verif_year in range(1968, 2021):

    list_per_lead = []
    for lead_year in range(10):
        
        init_year = verif_year - lead_year
        fn_CESM = base_dir + f"SMYLE_{init_year-1}-11-01_daily_ensemble.zarr"

        if fn_CESM not in _cache:
            ds0 = xr.open_zarr(fn_CESM)[var_map]
            ds0['PRECT'] = ds0['PRECT'] * 60*60*24 * 1000 # mm per day
            _cache[fn_CESM] = ds0.mean("member")

        ds_CESM = _cache[fn_CESM].sel(time=slice(f"{verif_year}-01-01", f"{verif_year}-12-31"))
        
        ds_max = ds_CESM[["PRECT", "TREFHTMX"]].max("time", skipna=True).rename(
            {"PRECT": "PRECT_max", "TREFHTMX": "TREFHTMX_max"}
        )
        ds_mean = ds_CESM[["PRECT", "TREFHT"]].mean("time", skipna=True).rename(
            {"PRECT": "PRECT_mean", "TREFHT": "TREFHT_mean"}
        )

        ds_merge = xr.merge([ds_max, ds_mean]).expand_dims(lead_year=[lead_year])
        list_per_lead.append(ds_merge)

    ds_per_verif = xr.concat(list_per_lead, dim="lead_year").expand_dims(valid_year=[verif_year])
    list_per_verif.append(ds_per_verif)

ds_all = xr.concat(list_per_verif, dim="valid_year")
ds_all = ds_all.chunk({"valid_year": -1, "lead_year": -1, "lat": 192, "lon": 288})

# %%
ds_all = ds_all.compute()

# %%
save_name = save_dir + 'CESM_minmax.zarr'
ds_all.to_zarr(save_name, mode='w')
print(save_name)
# Out:
# /glade/derecho/scratch/ksha/EPRI_data/METRICS_GLOBE/CESM_minmax.zarr

# %% [markdown]
# ### Detrend

# %%
def detrend_linear(da, dim="time"):
    t = xr.DataArray(np.arange(da.sizes[dim]), dims=dim, coords={dim: da[dim]})

    valid = np.isfinite(da)
    t_valid = t.where(valid)
    da_valid = da.where(valid)

    t_mean = t_valid.mean(dim, skipna=True)
    y_mean = da_valid.mean(dim, skipna=True)

    cov = ((t_valid - t_mean) * (da_valid - y_mean)).mean(dim, skipna=True)
    var = ((t_valid - t_mean) ** 2).mean(dim, skipna=True)

    slope = cov / var
    intercept = y_mean - slope * t_mean

    trend = slope * t + intercept
    return da - trend

# %%
fn = '/glade/derecho/scratch/ksha/EPRI_data/METRICS_GLOBE/CESM_minmax.zarr'
ds_CESM = xr.open_zarr(fn)

# %%
year_valid = np.arange(1968, 2021)

# remove linea trend separately on lead times
list_per_lead = []
for lead_year in range(10):
    ds_CESM_sub = ds_CESM.isel(lead_year=lead_year)
    ds_CESM_sub = ds_CESM_sub.sel(valid_year=year_valid)

    ds_CESM_detrend = ds_CESM_sub #.copy
    for v in ds_CESM_sub.data_vars:
        ds_CESM_detrend[v] = detrend_linear(ds_CESM_sub[v], dim="valid_year")
    list_per_lead.append(ds_CESM_detrend)

ds_all_detrend = xr.concat(list_per_lead, dim='lead_year')
ds_all_detrend = ds_all_detrend.rename({v: f"{v}_detrend" for v in ds_all_detrend.data_vars})
ds_all_detrend = ds_all_detrend.chunk({"valid_year": -1, "lead_year": -1, "lat": 192, "lon": 288})

# %%
save_name = save_dir + 'CESM_minmax_detrend.zarr'
ds_all_detrend.to_zarr(save_name, mode='w')
print(save_name)
# Out:
# /glade/derecho/scratch/ksha/EPRI_data/METRICS_GLOBE/CESM_minmax_detrend.zarr

# %% [markdown]
# ## Decadal

# %% [markdown]
# ### Default

# %%
save_dir = f'/glade/derecho/scratch/ksha/EPRI_data/METRICS_GLOBE/'
base_dir_CESM = '/glade/derecho/scratch/ksha/EPRI_data/CESM2_SMYLE/'
base_dir_ERA5 = '/glade/derecho/scratch/ksha/EPRI_data/ERA5_grid/'

var_map_CESM = ["TREFHT", "PRECT"]
var_map_ERA5 = {
    '2m_temperature': "TREFHT",
    'total_precipitation': "PRECT",
}


list_ERA5_metric = []
list_CESM_metric = []

for init_year in range(1968, 2012):
    # ====================================== #
    # CESM data prep
    fn_CESM = base_dir_CESM + f"SMYLE_{init_year-1}-11-01_daily_ensemble.zarr"
    ds_CESM = xr.open_zarr(fn_CESM)[var_map_CESM]
    ds_CESM = ds_CESM.mean("member")
    ds_CESM['PRECT'] = ds_CESM['PRECT'] * 60*60*24 * 1000 # mm per day
    
    ds_CESM = ds_CESM.sel(time=slice(f"{init_year}-01-01", f"{init_year+9}-12-31"))

    # 10-year mean of annual max
    ds_annmax_CESM = ds_CESM.resample(time="YS").max("time")
    ds_annmax_10y_mean_CESM = ds_annmax_CESM.mean("time")
    ds_annmax_10y_mean_CESM = ds_annmax_10y_mean_CESM.rename({'TREFHT': 'TREFHT_max', 'PRECT': 'PRECT_max'})

    # 10-year mean
    ds_mean_CESM = ds_CESM.mean("time")
    ds_mean_CESM = ds_mean_CESM.rename({"TREFHT": "TREFHT_mean", "PRECT": "PRECT_mean"})

    # merge
    ds_CESM_merge = xr.merge([ds_annmax_10y_mean_CESM, ds_mean_CESM]).expand_dims(init_year=[init_year,])
    list_CESM_metric.append(ds_CESM_merge)
    
    # ====================================== #
    # ERA5 data prep
    list_ERA5_daily = []
    list_ERA5_yearly = []
    
    ## each init_year has 10 lead years
    for i_lead in range(10):
        valid_year = init_year + i_lead
        fn_ERA5 = base_dir_ERA5 + f'ERA5_{valid_year}.zarr'
        ds_ERA5 = xr.open_zarr(fn_ERA5)[list(var_map_ERA5)].rename(var_map_ERA5)
        
        # gather daily and yearly 
        list_ERA5_daily.append(ds_ERA5)
        list_ERA5_yearly.append(ds_ERA5.max("time").expand_dims(valid_year=[valid_year,]))
        
    ds_daily_ERA5 = xr.concat(list_ERA5_daily, dim='time')
    ds_mean_ERA5 = ds_daily_ERA5.mean("time").rename({"TREFHT": "TREFHT_mean", "PRECT": "PRECT_mean"})
    
    ds_anmax_ERA5 = xr.concat(list_ERA5_yearly, dim='valid_year')
    ds_annmax_10y_mean_ERA5 = ds_anmax_ERA5.mean("valid_year").rename({'TREFHT': 'TREFHT_max', 'PRECT': 'PRECT_max'})
    
    ds_ERA5_merge = xr.merge([ds_mean_ERA5, ds_annmax_10y_mean_ERA5]).expand_dims(init_year=[init_year,])
    list_ERA5_metric.append(ds_ERA5_merge)

    # ========================================== #
    # checks
    assert ds_annmax_CESM.sizes["time"] == 10
    assert ds_daily_ERA5.time.dt.year.min().item() == init_year
    assert ds_daily_ERA5.time.dt.year.max().item() == init_year + 9

ds_CESM_metric = xr.concat(list_CESM_metric, dim='init_year')
ds_ERA5_metric = xr.concat(list_ERA5_metric, dim='init_year')

# %%
save_name = save_dir + 'CESM_minmax_10Y.zarr'
# ds_CESM_metric.to_zarr(save_name, mode='w')
print(save_name)
# Out:
# /glade/derecho/scratch/ksha/EPRI_data/METRICS_GLOBE/CESM_minmax_10Y.zarr

# %%
save_name = save_dir + 'ERA5_minmax_10Y.zarr'
# ds_ERA5_metric.to_zarr(save_name, mode='w')
print(save_name)
# Out:
# /glade/derecho/scratch/ksha/EPRI_data/METRICS_GLOBE/ERA5_minmax_10Y.zarr

# %% [markdown]
# ### Detrend

# %%
def detrend_linear(da, dim="time"):
    t = xr.DataArray(np.arange(da.sizes[dim]), dims=dim, coords={dim: da[dim]})

    valid = np.isfinite(da)
    t_valid = t.where(valid)
    da_valid = da.where(valid)

    t_mean = t_valid.mean(dim, skipna=True)
    y_mean = da_valid.mean(dim, skipna=True)

    cov = ((t_valid - t_mean) * (da_valid - y_mean)).mean(dim, skipna=True)
    var = ((t_valid - t_mean) ** 2).mean(dim, skipna=True)

    slope = cov / var
    intercept = y_mean - slope * t_mean

    trend = slope * t + intercept
    return da - trend

# %%
fn = '/glade/derecho/scratch/ksha/EPRI_data/METRICS_GLOBE/CESM_minmax_10Y.zarr'
ds_CESM = xr.open_zarr(fn)

# %%
ds_CESM_detrend = ds_CESM #.copy
for v in ds_CESM.data_vars:
    ds_CESM_detrend[v] = detrend_linear(ds_CESM[v], dim="init_year")

ds_CESM_detrend = ds_CESM_detrend.rename({v: f"{v}_detrend" for v in ds_CESM_detrend.data_vars})
ds_CESM_detrend = ds_CESM_detrend.chunk({"init_year": -1, "lat": 192, "lon": 288})

# %%
save_name = save_dir + 'CESM_minmax_10Y_detrend.zarr'
# ds_CESM_detrend.to_zarr(save_name, mode='w')
print(save_name)
# Out:
# /glade/derecho/scratch/ksha/EPRI_data/METRICS_GLOBE/CESM_minmax_10Y_detrend.zarr

# %%
fn = '/glade/derecho/scratch/ksha/EPRI_data/METRICS_GLOBE/ERA5_minmax_10Y.zarr'
ds_ERA5 = xr.open_zarr(fn)

# %%
ds_ERA5_detrend = ds_ERA5 #.copy
for v in ds_ERA5.data_vars:
    ds_ERA5_detrend[v] = detrend_linear(ds_ERA5[v], dim="init_year")

ds_ERA5_detrend = ds_ERA5_detrend.rename({v: f"{v}_detrend" for v in ds_ERA5_detrend.data_vars})
ds_ERA5_detrend = ds_ERA5_detrend.chunk({"init_year": -1, "lat": 192, "lon": 288})

# %%
save_name = save_dir + 'ERA5_minmax_10Y_detrend.zarr'
# ds_ERA5_detrend.to_zarr(save_name, mode='w')
print(save_name)
# Out:
# /glade/derecho/scratch/ksha/EPRI_data/METRICS_GLOBE/ERA5_minmax_10Y_detrend.zarr

# %%
ds_ERA5_detrend
# Out:
# <xarray.Dataset>
# Dimensions:              (init_year: 44, lat: 192, lon: 288)
# Coordinates:
#   * init_year            (init_year) int64 1968 1969 1970 ... 2009 2010 2011
#   * lat                  (lat) float64 -90.0 -89.06 -88.12 ... 88.12 89.06 90.0
#   * lon                  (lon) float64 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
# Data variables:
#     PRECT_max_detrend    (init_year, lat, lon) float64 dask.array<chunksize=(44, 192, 288), meta=np.ndarray>
#     PRECT_mean_detrend   (init_year, lat, lon) float64 dask.array<chunksize=(44, 192, 288), meta=np.ndarray>
#     TREFHT_max_detrend   (init_year, lat, lon) float64 dask.array<chunksize=(44, 192, 288), meta=np.ndarray>
#     TREFHT_mean_detrend  (init_year, lat, lon) float64 dask.array<chunksize=(44, 192, 288), meta=np.ndarray>
